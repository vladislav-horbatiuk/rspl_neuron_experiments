# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import pandas as pd

import os
import random
print(os.getcwd())
# Out:
# /home/ivan/my_projects/nau_forecasting

# %%
ts_names = os.listdir('UCRArchive_2018')
print(ts_names)
# Out:
# ['ECG200', 'DistalPhalanxOutlineCorrect', 'PhalangesOutlinesCorrect', 'FreezerRegularTrain', 'FaceFour', 'PowerCons', 'Missing_value_and_variable_length_datasets_adjusted', 'PigCVP', 'ToeSegmentation2', 'UMD', 'GunPointMaleVersusFemale', 'BME', 'SemgHandGenderCh2', 'DistalPhalanxOutlineAgeGroup', 'BeetleFly', 'ACSF1', 'Chinatown', 'HandOutlines', 'GunPointOldVersusYoung', 'UWaveGestureLibraryY', 'GunPoint', 'UWaveGestureLibraryAll', 'Beef', 'Fish', 'Fungi', 'Adiac', 'Lightning7', 'FordA', 'SwedishLeaf', 'ECGFiveDays', 'WormsTwoClass', 'GestureMidAirD3', 'FaceAll', 'BirdChicken', 'PickupGestureWiimoteZ', 'TwoLeadECG', 'FacesUCR', 'ScreenType', 'CricketX', 'Trace', 'Plane', 'PigArtPressure', 'Symbols', 'MedicalImages', 'MiddlePhalanxOutlineAgeGroup', 'CinCECGTorso', 'FreezerSmallTrain', 'ProximalPhalanxOutlineAgeGroup', 'Yoga', 'ProximalPhalanxTW', 'Wine', 'ProximalPhalanxOutlineCorrect', 'ECG5000', 'Coffee', 'GesturePebbleZ1', 'ElectricDevices', 'FiftyWords', 'AllGestureWiimoteZ', 'Se
# ...

# %%
ts_name = random.choice(ts_names)
df1 = pd.read_csv(f'UCRArchive_2018/{ts_name}/{ts_name}_TRAIN.tsv', delimiter='\t', header=None).transpose()

IDX = random.randint(0, len(df1.columns) - 1)
print(ts_name)
print(IDX)
print(df1[IDX][0])
plt.plot(range(len(df1[IDX]) - 1), df1[IDX][1:])
# Out:
# EthanolLevel
# 452
# 3.0
# <img src="data:image/png;base64,..." width="640">
